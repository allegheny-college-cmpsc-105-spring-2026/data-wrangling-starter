# %% [markdown]
# TODO: Click on the badge, then `Copy to Drive` before continuing.

# %% [markdown]
# TODO: double click and replace this text with your name

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-wrangling-starter/blob/main/data_wrangling_starter.ipynb)

# %% [markdown]
# # Data Wrangling Lab

# %% [markdown]
# ## Add Your Name Here

# %% [markdown]
# Freshly gathered datasets often contain errors and inconsistencies. Data wrangling refers to the process of cleaning data to get rid of any errors, typos, and unreliable or unusable data prior to data exploration or analysis.
#
# In this lab, you will work with a real-world dataset, wrangle the data, and present some preliminary visualizations.
#
# The data you will use comes from the Trending YouTube Video Statistics dataset available on Kaggle:
# https://www.kaggle.com/datasets/datasnaek/youtube-new?resource=download
#
# This dataset contains information about trending YouTube videos, including metrics such as views, likes, dislikes, comments, category, and publish time. These variables allow you to explore what characteristics are associated with popular content.
#
# ## Goals
#
# Your goals are:
#
# - load and inspect a real-world dataset
# - wrangle the data
# - export a clean CSV file
# - conduct an exploration
# - submit the clean CSV file and this notebook file to GitHub
#
# Don't forget to answer all `T O D O` markers and to remove the markers.
#
# ## Deadline
#
# This lab should be completed during the lab meeting time, but modifations may be made until the official deadline of 4:15pm on April 7th.
#
# ## Learning Outcomes
#
# By completing this lab you will:
#
# - clean and organize real-world data
# - handle missing or inconsistent values
# - transform and create new variables
# - conduct an exploration
# - create visualizations
# - write a report in a markdown cell
# - update a GitHub Repository
# - check gatorgrade in GitHub Actions
#
# ## Reminders
#
# - Refer to previous materials to learn how to use Notebooks in Google Colab, make your work accessible, submit, and check your work.
#
# ## Saving Your Work
#
# Saving your work and making it accessible is a required part of all labs.
#
# ### Accessability Part 1
#
# <font color="red">Ensure the clean CSV filename is `USvideos.csv`</font>
#
# Update the Colab filename to be `data_wrangling.ipynb`.
#
# Make sure that all cells have been executed and are SHOWING their outputs.
#
# ### Saving
#
# I would recommend a workflow of `Copy to Drive --> editing/running/testing --> downloading`. You should have already hit `Copy to Drive`, but if you haven't, then please do so now. Then go ahead and download the file from the menu at the top of the Colab interface. File > Download > Download ipynb
#
# ### Accessibility Part 2
#
# If you are satisfied with your work, you can now upload the downloaded file to your GitHub repo!
#
# - Use GitHub to upload the file.
#   - Next to the green code button in GitHub, you will see an `add file` button. Click that, then choose the downloaded notebook from your computer.
#
# ## Checking Your Work
#
# ### Check your file output
#
# Once your file is uploaded, please open it on GitHub. All the outputs and plots should be showing. If they are not showing, this means that not all code cells were executed before you downloaded your file.
#
# ### Check GitHub Actions
#
# In GitHub, go to the Actions tab. Click on the top Action to see a report about your T O D Os. If the T O D Os have been done and deleted, then the actions will show that gatorgrade reports 100%. This is not your grade, but it is a good indication that you did not forget to do something.
#
# If you see remaining T O D Os, then you may want to edit and update your file.

# %% [markdown]
# # Data Wrangling

# %%
# TODO: Run this cell

# This code cell makes pre-existing tools available for wrangling and exploration

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact # pre existing code for interaction

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/data-wrangling-starter/main/data/USvideos.csv',
    sep=',',
    skiprows=0
)

# %%
# TODO: write a line of code to look at the first few rows of df

# %%
# TODO: write a line of code to check how many rows and columns are in df

# %%
# TODO: write a line of code to print out the column names in df

# %%
# OPTIONAL: change any column names as needed, and print them out again

# %%
# TODO: isolate the tags column
# TODO: save that column into a variable like junk_df
# Once it is saved, remove it from df to make df cleaner

# %%
# TODO: isolate the description column
# TODO: add that column into your previous junk_df
# Once it is saved, remove it from df to make df cleaner

# %%
# TODO: fix the trending_date formatting by splitting on '.'
# TODO: create readable pieces "trend_year", "trend_day", and "trend_month"
# TODO: if everything looks good, add three columns to df

# %%
# TODO: add the old date column into junk_df
# TODO: then remove the old date column and the non-year new column from df

# %%
# TODO: convert publish_time to datetime
# TODO: create a publish year column
# TODO: if everything looks good, add the cleaned column to df

# %%
# TODO: rebuild trending_date as a proper datetime
# TODO: calculate age in days: how many days between publish time and trending date
# TODO: if everything looks good, add the cleaned columns to df

# %% [markdown]
# # Conduct an Exploration

# %%
# TODO: convert important columns to numeric
# TODO: 
# Are the videos with the most views:
# 	- newer or older?
# 	- associated with more likes?
# 	- associated with more comments?
# 	- concentrated in certain categories?

# Clear out memory (doesn't impact the visualization, but keeps the computer happy)
plt.close('all')

# Make a blank canvas
plt.figure(figsize=(12,12))
plt.suptitle('Factors Contributing to Views')

plt.subplot(2,2,1)
plt.title('1. Views vs Category')
# TODO: make a scatter plot. Assume the title follows the Y vs X convention

# TODO: label the y axis

# TODO: label the x axis

# OPTIONAL: use plt.xticks(rotation=) to make the figure more legible



plt.subplot(2,2,2)
plt.title('2. Views vs Likes')
# TODO: make a scatter plot. Assume the title follows the Y vs X convention

# TODO: label the y axis

# TODO: label the x axis

# OPTIONAL: use plt.xticks(rotation=) to make the figure more legible


plt.subplot(2,2,3)
plt.title('3. Views vs Comments')
# TODO: make a scatter plot. Assume the title follows the Y vs X convention

# TODO: label the y axis

# TODO: label the x axis

# OPTIONAL: use plt.xticks(rotation=) to make the figure more legible


plt.subplot(2,2,4)
plt.title('4. Views vs Age')
# TODO: make a scatter plot. Assume the title follows the Y vs X convention

# TODO: label the y axis

# TODO: label the x axis

# OPTIONAL: use plt.xticks(rotation=) to make the figure more legible




# TODO: reveal everything

# %% [markdown]
# # Report

# %% [markdown]
# ### What this was lab about
#
# TODO: Briefly summarize what this lab was about and what you did at a high level.
#
# ### Methods
#
# TODO: Briefly talk about the methods you used to wrangle the data and any specific functions that helped you with the wrangling.
#
# ### Findings
#
# TODO: Briefly state what you found out about by exploring the data. Please refer to the figures you made above. For example, "As shown in figure 1..."
#
# TODO: Be sure to mention all four figures.
#
# ### Discussion
#
# TODO: Explain whether these findings make sense and whether they are strong or weak relationships.
#
# TODO: Discuss whether these relationships imply causation or just association.
#
# TODO: Explain what could be done to strengthen your confidence in the findings (e.g., more data, statistical tests, controlling variables).
#
# TODO: Briefly mention if you noticed any issues with the data wrangling process (e.g., date formatting, missing values, large numbers).
#
# TODO: Reflect on the dataset quality:
# - Are values like views, likes, and comments always reliable?
# - Could there be bias (e.g., trending algorithm, bots, or timing)?
#
# ### Future directions
#
# TODO: Briefly state what could be explored within the data in the future.
